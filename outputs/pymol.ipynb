# %%
import selfies as sf
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
# 1. SELFIES to SMILES
selfies_str = "[C][C][=C][C][=C][Branch2][Ring1][#Branch1][C][=Branch1][C][=O][N][C][C][=Branch1][C][=O][N][C][=C][C][=C][Branch1][C][F][C][=C][Ring1][#Branch1][C][=C][Ring2][Ring1][Ring2][C]" # Example: Benzene
smiles_str = sf.decoder(selfies_str)
